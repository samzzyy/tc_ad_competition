# %%
import pandas as pd
import numpy as np
import time,datetime

# %%
from sklearn import preprocessing
from sklearn.model_selection import KFold, RepeatedKFold
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.cross_validation import train_test_split
# Out:
# /home/zhangyier/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def datetime2SecondsFrom1970(timeDateStr:str):
    time1=datetime.datetime.strptime(timeDateStr,"%Y-%m-%d %H:%M:%S")
    secondsFrom1970=time.mktime(time1.timetuple())
    return secondsFrom1970

def seconds2Datetime(seconds_from_1970):
    timeArray = time.localtime(seconds_from_1970)#1970秒数
    otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
    datetime1=datetime.datetime.strptime(otherStyleTime, "%Y-%m-%d %H:%M:%S")
    return str(datetime1)
def datetime2SecondsFrom1970_s(timeDateStr:str):
    time1=datetime.datetime.strptime(timeDateStr,"%Y%m%d%H%M%S")
    secondsFrom1970=time.mktime(time1.timetuple())
    return int(secondsFrom1970)
def smape(valid_,label_valid_array):
    temp_differ_abs=abs(valid_-label_valid_array)
    temp_sum_mod_2=(valid_+label_valid_array)/2
    print(40*(1-(sum(temp_differ_abs/temp_sum_mod_2)/label_valid_array.shape[0]/2)))
    return sum(temp_differ_abs/temp_sum_mod_2)/label_valid_array.shape[0]

# %%
ad_sample_test=pd.read_csv('../Data/A_preliminary_generate/Test/ad_sample_feature1phase_test.csv')

ad_sample_test['have_create_seconds']=0

ad_sample_test['have_create_seconds'][
    ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190319235959')]=datetime2SecondsFrom1970_s('20190320235959')-ad_sample_test['create_time'][ad_sample_test['create_time']
                                                                                                                                                 <=datetime2SecondsFrom1970_s('20190319235959')]
#预测3月20日周三

ad_sample_test['have_create_seconds'][(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190319235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190320235959'))]=datetime2SecondsFrom1970_s('20190321235959')-ad_sample_test['create_time'][
(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190319235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190320235959'))]
#3月21日周四

ad_sample_test['have_create_seconds'][(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190320235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190321235959'))]=datetime2SecondsFrom1970_s('20190322235959')-ad_sample_test['create_time'][
(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190320235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190321235959'))]
#3月22日周五

ad_sample_test['have_create_seconds'][(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190321235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190322235959'))]=datetime2SecondsFrom1970_s('20190323235959')-ad_sample_test['create_time'][
(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190321235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190322235959'))]
#3月23日周六

ad_sample_test['have_create_seconds'][(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190322235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190323235959'))]=datetime2SecondsFrom1970_s('20190324235959')-ad_sample_test['create_time'][
(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190322235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190323235959'))]
#3月24日周日

ad_sample_test['have_create_seconds'][(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190323235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190324235959'))]=datetime2SecondsFrom1970_s('20190325235959')-ad_sample_test['create_time'][
(ad_sample_test['create_time']>datetime2SecondsFrom1970_s('20190323235959'))&
(ad_sample_test['create_time']<=datetime2SecondsFrom1970_s('20190324235959'))]
#3月25日周一
# Out:
# /home/zhangyier/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /home/zhangyier/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
ad_static_feature=pd.read_csv("../Data/A_preliminary/testA/ad_static_feature.out",header=None,sep='\t',
                             names=['ad_id','create_time','ad_account_id','commodity_id','commodity_type','ad_trades_id','ad_size',
                             ])
# Out:
# /home/zhangyier/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def train_set_ready(train_set_name_list,ad_static_feature):
    train_set_3_19=pd.read_csv('../Data/A_preliminary_generate/Train/ad_sample_0319_feature1phase_train.csv')
    valid_set_from_3_19=train_set_3_19[:2000]#设定验证集
    train_set_3_19=train_set_3_19[2000:]
    train_set=train_set_3_19
    for day in train_set_name_list:
        print("date",day)
        if day =='0319':
            continue
        train_set_date=pd.read_csv('../Data/A_preliminary_generate/Train/ad_sample_'+day+'_feature1phase_train.csv')
        train_set=pd.concat([train_set,train_set_date],axis=0)
        train_set['ad_trades_id']=train_set['ad_trades_id'].apply(lambda x: int(str(x).split(',')[0]))
        #3月18,19日两天有275条样本交易行业超过一个，但是test_sample中不存在这样的样本，直接取第一个
    train_set.drop(columns='create_time',inplace=True)
    valid_set_from_3_19.drop(columns='create_time',inplace=True)
    print('train\n',train_set.info())
    train_set=train_set.merge(ad_static_feature[['ad_id','create_time']],on='ad_id',how='inner')
    valid_set_from_3_19=valid_set_from_3_19.merge(ad_static_feature[['ad_id','create_time']],on='ad_id',how='inner')
    train_set['have_create_seconds']=train_set['end_time']-train_set['create_time']
    valid_set_from_3_19['have_create_seconds']=valid_set_from_3_19['end_time']-valid_set_from_3_19['create_time']
    print('valid\n',valid_set_from_3_19.info())
    
    print("drop duplicates:\n",train_set.shape[0])
    train_set.drop_duplicates(inplace=True)
    print(train_set.shape[0])#去重
    train_set=train_set[(train_set['hold_time']>10800)]#持续时间需要超过三个小时的样本
    # train_set=train_set[(train_set['audience_orientation_nums']>0)]#定向人群数量为0的是有问题的
    train_set.reset_index(inplace=True)
    
    return train_set,valid_set_from_3_19

# %%
columns_list=[
    # 'ad_id','audience_targeting','end_time','ad_account_id','commodity_id','commodity_type','ad_trades_id','ad_size','hold_time',
    #  'create_time','sample_id', 'exposure_ad_id',
     'bid','audience_orientation_nums','0000_0030','0030_0100','0100_0130','0130_0200','0200_0230','0230_0300','0300_0330',
    '0330_0400','0400_0430','0430_0500','0500_0530','0530_0600','0600_0630','0630_0700','0700_0730','0730_0800','0800_0830','0830_0900',
    '0900_0930','0930_1000','1000_1030','1030_1100','1100_1130','1130_1200','1200_1230','1230_1300','1300_1330','1330_1400','1400_1430','1430_1500',
    '1500_1530','1530_1600','1600_1630','1630_1700','1700_1730','1730_1800','1800_1830','1830_1900','1900_1930','1930_2000','2000_2030','2030_2100',
    '2100_2130','2130_2200','2200_2230','2230_2300','2300_2330','2330_2400',
    'ad_id_history_exposure_times','ad_id_bid_mean','ad_id_bid_var','ad_id_pctr_mean','ad_id_pctr_var','ad_id_quality_ecpm_mean',
    'ad_id_quality_ecpm_var','ad_id_total_ecpm_mean','ad_id_total_ecpm_var', 
    'account_id_history_exposure_times','account_id_bid_mean','account_id_bid_var','account_id_pctr_mean','account_id_pctr_var',
    'account_id_quality_ecpm_mean','account_id_quality_ecpm_var','account_id_total_ecpm_mean','account_id_total_ecpm_var',
    'commodity_id_history_exposure_times','commodity_id_bid_mean','commodity_id_bid_var','commodity_id_pctr_mean','commodity_id_pctr_var',
    'commodity_id_quality_ecpm_mean','commodity_id_quality_ecpm_var','commodity_id_total_ecpm_mean','commodity_id_total_ecpm_var',
    'commodity_type_history_exposure_times','commodity_type_bid_mean','commodity_type_bid_var','commodity_type_pctr_mean',
    'commodity_type_pctr_var','commodity_type_quality_ecpm_mean','commodity_type_quality_ecpm_var','commodity_type_total_ecpm_mean',
    'commodity_type_total_ecpm_var',
    'trades_id_history_exposure_times','trades_id_bid_mean','trades_id_bid_var','trades_id_pctr_mean','trades_id_pctr_var',
    'trades_id_quality_ecpm_mean','trades_id_quality_ecpm_var','trades_id_total_ecpm_mean','trades_id_total_ecpm_var',
    'week_day','have_create_seconds']
def feture_fixed(columns_list,train_set,ad_sample_test,valid_set_from_3_19):
    print('feature fixed')
    label=train_set['exposure_times']
    train=train_set[columns_list]
    test=ad_sample_test[columns_list]
    label_validation=valid_set_from_3_19['exposure_times']
    validation=valid_set_from_3_19[columns_list]
    
    train_array=train.values
    label_array=label.values
    test_array=test.values
    label_valid_array=label_validation.values
    validtion_array=validation.values
    return train_array,label_array,test_array,label_valid_array,validtion_array

# %%
def xgb_train(train_array,label_array,test_array,label_valid_array,validtion_array):
    xgb_params = {'eta': 0.005, 'max_depth': 10, 'subsample': 0.8, 'colsample_bytree': 0.8,
              'objective': 'reg:linear', 'eval_metric': 'rmse', 'silent': True, 'nthread': 10}
    folds = KFold(n_splits=5, shuffle=True, random_state=2019)
    oof_xgb = np.zeros(len(train_array))
    predictions_xgb = np.zeros(len(test_array))
    valid_xgb=np.zeros(len(label_valid_array))
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_array, label_array)):
        print("fold n°{}".format(fold_ + 1))
        trn_data = xgb.DMatrix(train_array[trn_idx], label_array[trn_idx])
        val_data = xgb.DMatrix(train_array[val_idx], label_array[val_idx])

        watchlist = [(trn_data, 'train'), (val_data, 'valid_data')]
        clf = xgb.train(dtrain=trn_data, num_boost_round=20000, evals=watchlist, early_stopping_rounds=200,
                        verbose_eval=100, params=xgb_params)
        oof_xgb[val_idx] = clf.predict(xgb.DMatrix(train_array[val_idx]), ntree_limit=clf.best_ntree_limit)
        predictions_xgb += clf.predict(xgb.DMatrix(test_array), ntree_limit=clf.best_ntree_limit) / folds.n_splits
        valid_xgb += clf.predict(xgb.DMatrix(validtion_array), ntree_limit=clf.best_ntree_limit) / folds.n_splits

    print("CV score: {:<8.8f}".format(mean_squared_error(oof_xgb, label_array)))
    print("cv smape:",smape(oof_xgb, label_array))
    print('------------------------------------------------------------------------------------------------------------------')
    print('validation:',mean_squared_error(valid_xgb, label_valid_array))
    print(smape(valid_xgb,label_valid_array))
    print('------------------------------------------------------------------------------------------------------------------')

# %%
def offline_xgb_test(train_set_name_list,ad_static_feature,ad_sample_test,columns_list):
    train_set,valid_set_from_3_19=train_set_ready(train_set_name_list,ad_static_feature)
    train_array,label_array,test_array,label_valid_array,validtion_array=feture_fixed(columns_list,train_set,ad_sample_test,valid_set_from_3_19)
    xgb_train(train_array,label_array,test_array,label_valid_array,validtion_array)

# %%
train_set_name_all_list=['0319','0318','0317','0316','0315','0314','0313','0312','0311','0310',]
for index in range(6,len(train_set_name_all_list)+1):
    train_set_name_list=train_set_name_all_list[:index]
    offline_xgb_test(train_set_name_list,ad_static_feature,ad_sample_test,columns_list)
# Out:
# date 0319
# date 0318
# date 0317
# date 0316
# date 0315
# date 0314
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78418 entries, 2000 to 16336
# Columns: 108 entries, ad_id to week_day
# dtypes: float64(46), int64(61), object(1)
# memory usage: 65.2+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78418 entries, 0 to 78417
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 66.4+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 1.7+ MB
# valid
#  None
# drop duplicates:
#  78418
# 78418
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75076 entries, 0 to 75075
# Columns: 111 entries, index to have_create_seconds
# dtypes: float64(46), int64(64), object(1)
# memory usage: 63.6+ MB
# fold n°1
# [0]	train-rmse:109.528	valid_data-rmse:55.9057
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:80.0261	valid_data-rmse:41.0122
# [200]	train-rmse:59.4248	valid_data-rmse:36.1148
# [300]	train-rmse:45.222	valid_data-rmse:36.6465
# [400]	train-rmse:35.3825	valid_data-rmse:39.3575
# Stopping. Best iteration:
# [220]	train-rmse:56.0821	valid_data-rmse:35.8753
#
# fold n°2
# [0]	train-rmse:101.135	valid_data-rmse:101.39
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:74.5933	valid_data-rmse:81.4552
# [200]	train-rmse:56.7375	valid_data-rmse:72.2895
# [300]	train-rmse:43.8854	valid_data-rmse:67.3188
# [400]	train-rmse:34.711	valid_data-rmse:65.2253
# [500]	train-rmse:28.0343	valid_data-rmse:64.7037
# [600]	train-rmse:23.1216	valid_data-rmse:64.9267
# [700]	train-rmse:19.4472	valid_data-rmse:65.4295
# Stopping. Best iteration:
# [534]	train-rmse:26.2115	valid_data-rmse:64.6366
#
# fold n°3
# [0]	train-rmse:98.9452	valid_data-rmse:109.538
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:73.8851	valid_data-rmse:91.0092
# [200]	train-rmse:56.7893	valid_data-rmse:82.5515
# [300]	train-rmse:44.5745	valid_data-rmse:77.831
# [400]	train-rmse:35.6317	valid_data-rmse:77.9261
# [500]	train-rmse:29.1991	valid_data-rmse:79.5482
# Stopping. Best iteration:
# [345]	train-rmse:40.2212	valid_data-rmse:77.2787
#
# fold n°4
# [0]	train-rmse:100.28	valid_data-rmse:104.54
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:73.1363	valid_data-rmse:91.4849
# [200]	train-rmse:54.8292	valid_data-rmse:84.0096
# [300]	train-rmse:41.4071	valid_data-rmse:78.8332
# [400]	train-rmse:32.1914	valid_data-rmse:75.6304
# [500]	train-rmse:25.5123	valid_data-rmse:73.2775
# [600]	train-rmse:20.8518	valid_data-rmse:71.6882
# [700]	train-rmse:17.4792	valid_data-rmse:70.7272
# [800]	train-rmse:15.074	valid_data-rmse:69.8902
# [900]	train-rmse:13.25	valid_data-rmse:69.4128
# [1000]	train-rmse:11.8604	valid_data-rmse:68.9251
# [1100]	train-rmse:10.8658	valid_data-rmse:68.5449
# [1200]	train-rmse:10.0785	valid_data-rmse:68.2404
# [1300]	train-rmse:9.5168	valid_data-rmse:67.9983
# [1400]	train-rmse:9.09731	valid_data-rmse:67.8367
# [1500]	train-rmse:8.75109	valid_data-rmse:67.7058
# [1600]	train-rmse:8.50493	valid_data-rmse:67.6238
# [1700]	train-rmse:8.28369	valid_data-rmse:67.5787
# [1800]	train-rmse:8.09239	valid_data-rmse:67.5291
# [1900]	train-rmse:7.93053	valid_data-rmse:67.4996
# [2000]	train-rmse:7.78018	valid_data-rmse:67.4742
# [2100]	train-rmse:7.64393	valid_data-rmse:67.4562
# [2200]	train-rmse:7.50898	valid_data-rmse:67.4451
# [2300]	train-rmse:7.37119	valid_data-rmse:67.4376
# [2400]	train-rmse:7.24165	valid_data-rmse:67.4341
# [2500]	train-rmse:7.10753	valid_data-rmse:67.419
# [2600]	train-rmse:6.9664	valid_data-rmse:67.4134
# [2700]	train-rmse:6.84842	valid_data-rmse:67.4058
# [2800]	train-rmse:6.72608	valid_data-rmse:67.402
# [2900]	train-rmse:6.61403	valid_data-rmse:67.3905
# [3000]	train-rmse:6.49331	valid_data-rmse:67.3885
# [3100]	train-rmse:6.37534	valid_data-rmse:67.3845
# [3200]	train-rmse:6.26663	valid_data-rmse:67.3776
# [3300]	train-rmse:6.16371	valid_data-rmse:67.3759
# [3400]	train-rmse:6.05589	valid_data-rmse:67.3747
# [3500]	train-rmse:5.94887	valid_data-rmse:67.3785
# Stopping. Best iteration:
# [3387]	train-rmse:6.07018	valid_data-rmse:67.3731
#
# fold n°5
# [0]	train-rmse:95.2223	valid_data-rmse:122.016
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:69.0063	valid_data-rmse:107.034
# [200]	train-rmse:51.1805	valid_data-rmse:99.8854
# [300]	train-rmse:38.8393	valid_data-rmse:97.3
# [400]	train-rmse:30.3338	valid_data-rmse:96.583
# [500]	train-rmse:24.4693	valid_data-rmse:96.6839
# Stopping. Best iteration:
# [376]	train-rmse:32.1118	valid_data-rmse:96.5379
#
# CV score: 5059.07200389
# 11.136077365338103
# cv smape: 1.4431961317330948
# ------------------------------------------------------------------------------------------------------------------
# validation: 28632.847948034283
# 9.61177164726049
# 1.5194114176369755
# ------------------------------------------------------------------------------------------------------------------
# date 0319
# date 0318
# date 0317
# date 0316
# date 0315
# date 0314
# date 0313
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94204 entries, 2000 to 15785
# Columns: 108 entries, ad_id to week_day
# dtypes: float64(46), int64(61), object(1)
# memory usage: 78.3+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94204 entries, 0 to 94203
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 79.8+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 1.7+ MB
# valid
#  None
# drop duplicates:
#  94204
# 94204
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89928 entries, 0 to 89927
# Columns: 111 entries, index to have_create_seconds
# dtypes: float64(46), int64(64), object(1)
# memory usage: 76.2+ MB
# fold n°1
# [0]	train-rmse:103.432	valid_data-rmse:92.7016
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:75.7919	valid_data-rmse:71.2321
# [200]	train-rmse:56.896	valid_data-rmse:58.7087
# [300]	train-rmse:44.0089	valid_data-rmse:51.198
# [400]	train-rmse:34.8973	valid_data-rmse:47.5038
# [500]	train-rmse:28.1774	valid_data-rmse:45.527
# [600]	train-rmse:23.6214	valid_data-rmse:44.6503
# [700]	train-rmse:20.0223	valid_data-rmse:44.426
# [800]	train-rmse:17.2398	valid_data-rmse:44.4203
# [900]	train-rmse:15.1302	valid_data-rmse:44.6003
# Stopping. Best iteration:
# [747]	train-rmse:18.6387	valid_data-rmse:44.3493
#
# fold n°2
# [0]	train-rmse:106.216	valid_data-rmse:78.3875
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:76.7971	valid_data-rmse:64.4146
# [200]	train-rmse:57.2482	valid_data-rmse:60.6507
# [300]	train-rmse:44.0324	valid_data-rmse:60.5875
# [400]	train-rmse:34.8212	valid_data-rmse:62.1778
# Stopping. Best iteration:
# [254]	train-rmse:49.4134	valid_data-rmse:60.1465
#
# fold n°3
# [0]	train-rmse:91.1873	valid_data-rmse:134.473
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:67.8847	valid_data-rmse:111.853
# [200]	train-rmse:52.3014	valid_data-rmse:97.8611
# [300]	train-rmse:40.8457	valid_data-rmse:88.8759
# [400]	train-rmse:32.8153	valid_data-rmse:83.7038
# [500]	train-rmse:26.9323	valid_data-rmse:80.2767
# [600]	train-rmse:22.5878	valid_data-rmse:78.1431
# [700]	train-rmse:19.1735	valid_data-rmse:77.025
# [800]	train-rmse:16.5588	valid_data-rmse:76.3128
# [900]	train-rmse:14.6425	valid_data-rmse:75.9885
# [1000]	train-rmse:13.1007	valid_data-rmse:75.9286
# [1100]	train-rmse:11.9926	valid_data-rmse:75.854
# [1200]	train-rmse:11.0987	valid_data-rmse:75.8465
# [1300]	train-rmse:10.4286	valid_data-rmse:75.8379
# [1400]	train-rmse:9.90977	valid_data-rmse:75.9016
# Stopping. Best iteration:
# [1258]	train-rmse:10.6972	valid_data-rmse:75.8145
#
# fold n°4
# [0]	train-rmse:99.0934	valid_data-rmse:109.638
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:70.4042	valid_data-rmse:97.4724
# [200]	train-rmse:51.2051	valid_data-rmse:90.7446
# [300]	train-rmse:38.215	valid_data-rmse:87.0503
# [400]	train-rmse:29.4557	valid_data-rmse:85.2552
# [500]	train-rmse:23.302	valid_data-rmse:84.2527
# [600]	train-rmse:19.0354	valid_data-rmse:83.5745
# [700]	train-rmse:16.1663	valid_data-rmse:83.2129
# [800]	train-rmse:13.998	valid_data-rmse:82.9525
# [900]	train-rmse:12.4147	valid_data-rmse:82.8346
# [1000]	train-rmse:11.2647	valid_data-rmse:82.7463
# [1100]	train-rmse:10.4049	valid_data-rmse:82.6945
# [1200]	train-rmse:9.83517	valid_data-rmse:82.6468
# [1300]	train-rmse:9.37539	valid_data-rmse:82.6544
# [1400]	train-rmse:9.02772	valid_data-rmse:82.6526
# Stopping. Best iteration:
# [1268]	train-rmse:9.50237	valid_data-rmse:82.6325
#
# fold n°5
# [0]	train-rmse:105.757	valid_data-rmse:80.9732
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:76.6971	valid_data-rmse:63.8301
# [200]	train-rmse:57.1202	valid_data-rmse:56.8621
# [300]	train-rmse:43.173	valid_data-rmse:55.59
# [400]	train-rmse:33.6397	valid_data-rmse:57.6129
# Stopping. Best iteration:
# [289]	train-rmse:44.4777	valid_data-rmse:55.5434
#
# CV score: 4249.08622307
# 12.420502845458286
# cv smape: 1.3789748577270857
# ------------------------------------------------------------------------------------------------------------------
# validation: 29181.617087007435
# 11.34539065908729
# 1.4327304670456356
# ------------------------------------------------------------------------------------------------------------------
# date 0319
# date 0318
# date 0317
# date 0316
# date 0315
# date 0314
# date 0313
# date 0312
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109331 entries, 2000 to 15126
# Columns: 108 entries, ad_id to week_day
# dtypes: float64(46), int64(61), object(1)
# memory usage: 90.9+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109331 entries, 0 to 109330
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 92.6+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 1.7+ MB
# valid
#  None
# drop duplicates:
#  109331
# 109331
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104549 entries, 0 to 104548
# Columns: 111 entries, index to have_create_seconds
# dtypes: float64(46), int64(64), object(1)
# memory usage: 88.5+ MB
# fold n°1
# [0]	train-rmse:95.8277	valid_data-rmse:139.424
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:70.0181	valid_data-rmse:120.722
# [200]	train-rmse:52.352	valid_data-rmse:108.466
# [300]	train-rmse:40.559	valid_data-rmse:102.327
# [400]	train-rmse:32.1464	valid_data-rmse:98.4024
# [500]	train-rmse:26.0884	valid_data-rmse:95.8317
# [600]	train-rmse:21.6083	valid_data-rmse:94.4257
# [700]	train-rmse:18.2223	valid_data-rmse:93.5818
# [800]	train-rmse:15.7545	valid_data-rmse:92.973
# [900]	train-rmse:13.8444	valid_data-rmse:92.487
# [1000]	train-rmse:12.4093	valid_data-rmse:92.2242
# [1100]	train-rmse:11.4049	valid_data-rmse:92.1017
# [1200]	train-rmse:10.6495	valid_data-rmse:92.1505
# Stopping. Best iteration:
# [1085]	train-rmse:11.5345	valid_data-rmse:92.079
#
# fold n°2
# [0]	train-rmse:101.795	valid_data-rmse:121.529
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:75.2077	valid_data-rmse:102.421
# [200]	train-rmse:57.1655	valid_data-rmse:90.8174
# [300]	train-rmse:44.651	valid_data-rmse:85.1391
# [400]	train-rmse:35.4601	valid_data-rmse:81.8998
# [500]	train-rmse:29.1355	valid_data-rmse:80.5273
# [600]	train-rmse:24.0127	valid_data-rmse:80.0002
# [700]	train-rmse:20.0965	valid_data-rmse:79.6975
# [800]	train-rmse:17.1695	valid_data-rmse:79.5868
# [900]	train-rmse:14.9109	valid_data-rmse:79.5622
# [1000]	train-rmse:13.2652	valid_data-rmse:79.6584
# Stopping. Best iteration:
# [863]	train-rmse:15.6871	valid_data-rmse:79.5234
#
# fold n°3
# [0]	train-rmse:103.62	valid_data-rmse:115.225
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:77.735	valid_data-rmse:90.532
# [200]	train-rmse:59.5066	valid_data-rmse:75.6205
# [300]	train-rmse:46.5484	valid_data-rmse:66.5587
# [400]	train-rmse:37.3288	valid_data-rmse:60.5656
# [500]	train-rmse:30.6114	valid_data-rmse:56.4435
# [600]	train-rmse:25.4796	valid_data-rmse:53.7368
# [700]	train-rmse:21.4204	valid_data-rmse:51.9252
# [800]	train-rmse:18.3514	valid_data-rmse:50.5458
# [900]	train-rmse:15.9922	valid_data-rmse:49.5856
# [1000]	train-rmse:14.1911	valid_data-rmse:48.8918
# [1100]	train-rmse:12.8356	valid_data-rmse:48.3462
# [1200]	train-rmse:11.7579	valid_data-rmse:47.9905
# [1300]	train-rmse:10.9307	valid_data-rmse:47.7593
# [1400]	train-rmse:10.3369	valid_data-rmse:47.6102
# [1500]	train-rmse:9.873	valid_data-rmse:47.5038
# [1600]	train-rmse:9.50252	valid_data-rmse:47.437
# [1700]	train-rmse:9.21322	valid_data-rmse:47.373
# [1800]	train-rmse:8.97494	valid_data-rmse:47.3038
# [1900]	train-rmse:8.77062	valid_data-rmse:47.2633
# [2000]	train-rmse:8.59833	valid_data-rmse:47.2268
# [2100]	train-rmse:8.43273	valid_data-rmse:47.1986
# [2200]	train-rmse:8.29274	valid_data-rmse:47.1832
# [2300]	train-rmse:8.15466	valid_data-rmse:47.1698
# [2400]	train-rmse:8.02659	valid_data-rmse:47.1681
# [2500]	train-rmse:7.90508	valid_data-rmse:47.168
# [2600]	train-rmse:7.77914	valid_data-rmse:47.1611
# [2700]	train-rmse:7.65289	valid_data-rmse:47.1437
# [2800]	train-rmse:7.52946	valid_data-rmse:47.1381
# [2900]	train-rmse:7.419	valid_data-rmse:47.1362
# [3000]	train-rmse:7.30389	valid_data-rmse:47.1351
# [3100]	train-rmse:7.18995	valid_data-rmse:47.1362
# Stopping. Best iteration:
# [2997]	train-rmse:7.30542	valid_data-rmse:47.1345
#
# fold n°4
# [0]	train-rmse:115.694	valid_data-rmse:50.889
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:85.1681	valid_data-rmse:38.3854
# [200]	train-rmse:64.3878	valid_data-rmse:35.1739
# [300]	train-rmse:50.0707	valid_data-rmse:36.7764
# [400]	train-rmse:39.6263	valid_data-rmse:40.4621
# Stopping. Best iteration:
# [201]	train-rmse:64.2084	valid_data-rmse:35.1514
#
# fold n°5
# [0]	train-rmse:111.78	valid_data-rmse:78.8314
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:83.1541	valid_data-rmse:63.2019
# [200]	train-rmse:63.3007	valid_data-rmse:55.5893
# [300]	train-rmse:49.6055	valid_data-rmse:51.6818
# [400]	train-rmse:39.6561	valid_data-rmse:50.2515
# [500]	train-rmse:32.3137	valid_data-rmse:50.2214
# [600]	train-rmse:26.8739	valid_data-rmse:50.3817
# Stopping. Best iteration:
# [449]	train-rmse:35.8513	valid_data-rmse:50.0893
#
# CV score: 4153.76029610
# 13.152668956650974
# cv smape: 1.3423665521674513
# ------------------------------------------------------------------------------------------------------------------
# validation: 32065.957558009002
# 12.666276258314312
# 1.3666861870842844
# ------------------------------------------------------------------------------------------------------------------
# date 0319
# date 0318
# date 0317
# date 0316
# date 0315
# date 0314
# date 0313
# date 0312
# date 0311
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124824 entries, 2000 to 15492
# Columns: 108 entries, ad_id to week_day
# dtypes: float64(46), int64(61), object(1)
# memory usage: 103.8+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124824 entries, 0 to 124823
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 105.7+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 1.7+ MB
# valid
#  None
# drop duplicates:
#  124824
# 124824
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119541 entries, 0 to 119540
# Columns: 111 entries, index to have_create_seconds
# dtypes: float64(46), int64(64), object(1)
# memory usage: 101.2+ MB
# fold n°1
# [0]	train-rmse:116.472	valid_data-rmse:56.4138
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:85.1456	valid_data-rmse:42.2445
# [200]	train-rmse:63.5522	valid_data-rmse:40.5117
# [300]	train-rmse:48.5297	valid_data-rmse:44.2511
# Stopping. Best iteration:
# [172]	train-rmse:68.8185	valid_data-rmse:40.0488
#
# fold n°2
# [0]	train-rmse:109.431	valid_data-rmse:98.0364
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:80.847	valid_data-rmse:78.7335
# [200]	train-rmse:60.472	valid_data-rmse:74.222
# [300]	train-rmse:46.2695	valid_data-rmse:76.4181
# Stopping. Best iteration:
# [195]	train-rmse:61.2562	valid_data-rmse:74.1632
#
# fold n°3
# [0]	train-rmse:99.3325	valid_data-rmse:134.476
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:74.8746	valid_data-rmse:117.135
# [200]	train-rmse:57.5417	valid_data-rmse:107.203
# [300]	train-rmse:45.3935	valid_data-rmse:102.015
# [400]	train-rmse:36.3819	valid_data-rmse:99.2206
# [500]	train-rmse:29.6667	valid_data-rmse:97.4226
# [600]	train-rmse:24.6842	valid_data-rmse:96.1346
# [700]	train-rmse:20.8982	valid_data-rmse:95.6753
# [800]	train-rmse:17.9697	valid_data-rmse:95.3613
# [900]	train-rmse:15.7439	valid_data-rmse:95.1383
# [1000]	train-rmse:14.0754	valid_data-rmse:94.9683
# [1100]	train-rmse:12.8649	valid_data-rmse:94.834
# [1200]	train-rmse:11.9033	valid_data-rmse:94.762
# [1300]	train-rmse:11.142	valid_data-rmse:94.6824
# [1400]	train-rmse:10.548	valid_data-rmse:94.6526
# [1500]	train-rmse:10.0732	valid_data-rmse:94.5867
# [1600]	train-rmse:9.71983	valid_data-rmse:94.5334
# [1700]	train-rmse:9.42834	valid_data-rmse:94.5506
# [1800]	train-rmse:9.18506	valid_data-rmse:94.5351
# [1900]	train-rmse:8.99005	valid_data-rmse:94.5179
# [2000]	train-rmse:8.81758	valid_data-rmse:94.487
# [2100]	train-rmse:8.67633	valid_data-rmse:94.4704
# [2200]	train-rmse:8.53017	valid_data-rmse:94.4535
# [2300]	train-rmse:8.40613	valid_data-rmse:94.4526
# [2400]	train-rmse:8.2832	valid_data-rmse:94.4223
# [2500]	train-rmse:8.15683	valid_data-rmse:94.4054
# [2600]	train-rmse:8.03349	valid_data-rmse:94.3874
# [2700]	train-rmse:7.9018	valid_data-rmse:94.3792
# [2800]	train-rmse:7.77811	valid_data-rmse:94.3658
# [2900]	train-rmse:7.64616	valid_data-rmse:94.3572
# [3000]	train-rmse:7.52495	valid_data-rmse:94.3594
# [3100]	train-rmse:7.41671	valid_data-rmse:94.3574
# Stopping. Best iteration:
# [2924]	train-rmse:7.61247	valid_data-rmse:94.354
#
# fold n°4
# [0]	train-rmse:100.352	valid_data-rmse:131.213
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:74.0563	valid_data-rmse:110.852
# [200]	train-rmse:55.9105	valid_data-rmse:97.0805
# [300]	train-rmse:43.9163	valid_data-rmse:90.212
# [400]	train-rmse:35.2022	valid_data-rmse:86.5771
# [500]	train-rmse:28.5361	valid_data-rmse:83.781
# [600]	train-rmse:23.874	valid_data-rmse:81.5476
# [700]	train-rmse:20.5908	valid_data-rmse:80.7002
# [800]	train-rmse:17.968	valid_data-rmse:79.4916
# [900]	train-rmse:15.8471	valid_data-rmse:78.5258
# [1000]	train-rmse:14.1752	valid_data-rmse:77.9168
# [1100]	train-rmse:12.9281	valid_data-rmse:77.2553
# [1200]	train-rmse:11.9199	valid_data-rmse:76.743
# [1300]	train-rmse:11.1353	valid_data-rmse:76.3398
# [1400]	train-rmse:10.5153	valid_data-rmse:75.8595
# [1500]	train-rmse:10.0513	valid_data-rmse:75.5834
# [1600]	train-rmse:9.65838	valid_data-rmse:75.2855
# [1700]	train-rmse:9.37274	valid_data-rmse:75.102
# [1800]	train-rmse:9.12587	valid_data-rmse:74.9116
# [1900]	train-rmse:8.91753	valid_data-rmse:74.7461
# [2000]	train-rmse:8.74394	valid_data-rmse:74.6021
# [2100]	train-rmse:8.58607	valid_data-rmse:74.5512
# [2200]	train-rmse:8.43818	valid_data-rmse:74.4981
# [2300]	train-rmse:8.2952	valid_data-rmse:74.4142
# [2400]	train-rmse:8.174	valid_data-rmse:74.3133
# [2500]	train-rmse:8.05148	valid_data-rmse:74.2863
# [2600]	train-rmse:7.92778	valid_data-rmse:74.2603
# [2700]	train-rmse:7.81452	valid_data-rmse:74.2184
# [2800]	train-rmse:7.71055	valid_data-rmse:74.1952
# [2900]	train-rmse:7.6048	valid_data-rmse:74.1952
# [3000]	train-rmse:7.49568	valid_data-rmse:74.1874
# [3100]	train-rmse:7.38593	valid_data-rmse:74.1624
# [3200]	train-rmse:7.28619	valid_data-rmse:74.1526
# [3300]	train-rmse:7.17824	valid_data-rmse:74.156
# [3400]	train-rmse:7.0755	valid_data-rmse:74.152
# [3500]	train-rmse:6.9817	valid_data-rmse:74.1496
# [3600]	train-rmse:6.88264	valid_data-rmse:74.1516
# [3700]	train-rmse:6.78538	valid_data-rmse:74.1368
# [3800]	train-rmse:6.688	valid_data-rmse:74.1346
# [3900]	train-rmse:6.59086	valid_data-rmse:74.1309
# [4000]	train-rmse:6.50178	valid_data-rmse:74.1276
# [4100]	train-rmse:6.41903	valid_data-rmse:74.1207
# [4200]	train-rmse:6.33303	valid_data-rmse:74.1142
# [4300]	train-rmse:6.24812	valid_data-rmse:74.1086
# [4400]	train-rmse:6.16749	valid_data-rmse:74.1066
# [4500]	train-rmse:6.08847	valid_data-rmse:74.111
# Stopping. Best iteration:
# [4396]	train-rmse:6.17079	valid_data-rmse:74.1044
#
# fold n°5
# [0]	train-rmse:109.614	valid_data-rmse:97.4256
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:80.3953	valid_data-rmse:79.6358
# [200]	train-rmse:60.3525	valid_data-rmse:70.173
# [300]	train-rmse:46.4234	valid_data-rmse:65.5042
# [400]	train-rmse:36.3021	valid_data-rmse:63.1647
# [500]	train-rmse:29.1213	valid_data-rmse:62.3288
# [600]	train-rmse:23.7418	valid_data-rmse:62.106
# [700]	train-rmse:19.818	valid_data-rmse:62.0664
# [800]	train-rmse:16.8293	valid_data-rmse:62.1256
# Stopping. Best iteration:
# [696]	train-rmse:19.9562	valid_data-rmse:62.0483
#
# CV score: 5069.61406073
# 12.987835313658849
# cv smape: 1.3506082343170576
# ------------------------------------------------------------------------------------------------------------------
# validation: 28132.253137379037
# 11.74961902065576
# 1.412519048967212
# ------------------------------------------------------------------------------------------------------------------
# date 0319
# date 0318
# date 0317
# date 0316
# date 0315
# date 0314
# date 0313
# date 0312
# date 0311
# date 0310
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139827 entries, 2000 to 15002
# Columns: 108 entries, ad_id to week_day
# dtypes: float64(46), int64(61), object(1)
# memory usage: 116.3+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139827 entries, 0 to 139826
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 118.4+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 1.7+ MB
# valid
#  None
# drop duplicates:
#  139827
# 139827
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133954 entries, 0 to 133953
# Columns: 111 entries, index to have_create_seconds
# dtypes: float64(46), int64(64), object(1)
# memory usage: 113.4+ MB
# fold n°1
# [0]	train-rmse:96.0747	valid_data-rmse:129.597
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:71.1324	valid_data-rmse:109.652
# [200]	train-rmse:53.7237	valid_data-rmse:98.0315
# [300]	train-rmse:41.8531	valid_data-rmse:90.9014
# [400]	train-rmse:33.3856	valid_data-rmse:85.996
# [500]	train-rmse:27.224	valid_data-rmse:83.3246
# [600]	train-rmse:22.5765	valid_data-rmse:81.2894
# [700]	train-rmse:19.2261	valid_data-rmse:80.0449
# [800]	train-rmse:16.8396	valid_data-rmse:79.1486
# [900]	train-rmse:14.8668	valid_data-rmse:78.5046
# [1000]	train-rmse:13.4137	valid_data-rmse:77.8907
# [1100]	train-rmse:12.3153	valid_data-rmse:77.392
# [1200]	train-rmse:11.4289	valid_data-rmse:77.0188
# [1300]	train-rmse:10.7727	valid_data-rmse:76.712
# [1400]	train-rmse:10.2776	valid_data-rmse:76.4502
# [1500]	train-rmse:9.88434	valid_data-rmse:76.237
# [1600]	train-rmse:9.57719	valid_data-rmse:76.0164
# [1700]	train-rmse:9.31383	valid_data-rmse:75.8971
# [1800]	train-rmse:9.11611	valid_data-rmse:75.7697
# [1900]	train-rmse:8.94598	valid_data-rmse:75.6465
# [2000]	train-rmse:8.78636	valid_data-rmse:75.5801
# [2100]	train-rmse:8.64134	valid_data-rmse:75.5217
# [2200]	train-rmse:8.50617	valid_data-rmse:75.4676
# [2300]	train-rmse:8.37775	valid_data-rmse:75.4116
# [2400]	train-rmse:8.24364	valid_data-rmse:75.3752
# [2500]	train-rmse:8.12359	valid_data-rmse:75.3449
# [2600]	train-rmse:8.01741	valid_data-rmse:75.3001
# [2700]	train-rmse:7.90145	valid_data-rmse:75.275
# [2800]	train-rmse:7.78685	valid_data-rmse:75.2635
# [2900]	train-rmse:7.67296	valid_data-rmse:75.2585
# [3000]	train-rmse:7.56555	valid_data-rmse:75.2422
# [3100]	train-rmse:7.46872	valid_data-rmse:75.2332
# [3200]	train-rmse:7.36453	valid_data-rmse:75.2213
# [3300]	train-rmse:7.25936	valid_data-rmse:75.2137
# [3400]	train-rmse:7.1612	valid_data-rmse:75.2177
# Stopping. Best iteration:
# [3293]	train-rmse:7.26648	valid_data-rmse:75.2108
#
# fold n°2
# [0]	train-rmse:96.7004	valid_data-rmse:127.683
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:71.6907	valid_data-rmse:113.917
# [200]	train-rmse:54.5725	valid_data-rmse:106.48
# [300]	train-rmse:42.7625	valid_data-rmse:102.831
# [400]	train-rmse:34.0943	valid_data-rmse:101.417
# [500]	train-rmse:27.8485	valid_data-rmse:100.997
# [600]	train-rmse:23.0345	valid_data-rmse:101.208
# [700]	train-rmse:19.3673	valid_data-rmse:101.749
# Stopping. Best iteration:
# [525]	train-rmse:26.5473	valid_data-rmse:100.838
#
# fold n°3
# [0]	train-rmse:112.058	valid_data-rmse:58.3447
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:82.616	valid_data-rmse:44.087
# [200]	train-rmse:61.9084	valid_data-rmse:36.1468
# [300]	train-rmse:48.006	valid_data-rmse:32.2486
# [400]	train-rmse:37.6485	valid_data-rmse:30.275
# [500]	train-rmse:30.1579	valid_data-rmse:29.6248
# [600]	train-rmse:24.7763	valid_data-rmse:29.3711
# [700]	train-rmse:20.8144	valid_data-rmse:29.3966
# Stopping. Best iteration:
# [585]	train-rmse:25.4759	valid_data-rmse:29.3184
#
# fold n°4
# [0]	train-rmse:109.11	valid_data-rmse:77.5037
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:79.6875	valid_data-rmse:66.016
# [200]	train-rmse:59.3984	valid_data-rmse:64.73
# [300]	train-rmse:45.6586	valid_data-rmse:67.8784
# Stopping. Best iteration:
# [177]	train-rmse:63.3801	valid_data-rmse:64.5087
#
# fold n°5
# [0]	train-rmse:102.905	valid_data-rmse:106.148
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:76.0158	valid_data-rmse:86.4893
# [200]	train-rmse:57.8234	valid_data-rmse:76.2766
# [300]	train-rmse:44.6484	valid_data-rmse:70.9609
# [400]	train-rmse:35.0812	valid_data-rmse:68.381
# [500]	train-rmse:28.217	valid_data-rmse:67.3416
# [600]	train-rmse:23.4318	valid_data-rmse:67.1416
# [700]	train-rmse:19.6429	valid_data-rmse:67.4956
# Stopping. Best iteration:
# [596]	train-rmse:23.5999	valid_data-rmse:67.1383
#
# CV score: 5070.69797825
# 11.109917046080046
# cv smape: 1.4445041476959977
# ------------------------------------------------------------------------------------------------------------------
# validation: 27139.27044507296
# 10.94641585851512
# 1.452679207074244
# ------------------------------------------------------------------------------------------------------------------

# %%
train_set_name_list=['0319','0315','0314','0313','0312','0311','0310','0309','0308','0307','0306','0305','0304','0303']
offline_xgb_test(train_set_name_list,ad_static_feature,ad_sample_test,columns_list)
# Out:
# date 0319
# date 0315
# date 0313
# date 0312
# date 0311
# date 0310
# date 0308
# date 0304
# date 0303
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141844 entries, 2000 to 17398
# Columns: 108 entries, ad_id to week_day
# dtypes: float64(46), int64(61), object(1)
# memory usage: 118.0+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141844 entries, 0 to 141843
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 120.1+ MB
# train
#  None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Columns: 110 entries, ad_id to have_create_seconds
# dtypes: float64(46), int64(63), object(1)
# memory usage: 1.7+ MB
# valid
#  None
# drop duplicates:
#  141844
# 141844
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136816 entries, 0 to 136815
# Columns: 111 entries, index to have_create_seconds
# dtypes: float64(46), int64(64), object(1)
# memory usage: 115.9+ MB
# fold n°1
# [0]	train-rmse:85.0246	valid_data-rmse:102.731
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:62.9309	valid_data-rmse:93.7288
# [200]	train-rmse:47.9794	valid_data-rmse:89.2308
# [300]	train-rmse:37.4761	valid_data-rmse:86.6679
# [400]	train-rmse:30.1997	valid_data-rmse:85.6727
# [500]	train-rmse:24.6206	valid_data-rmse:85.0181
# [600]	train-rmse:20.5111	valid_data-rmse:84.6793
# [700]	train-rmse:17.4712	valid_data-rmse:84.64
# [800]	train-rmse:15.0793	valid_data-rmse:84.6768
# Stopping. Best iteration:
# [641]	train-rmse:19.1994	valid_data-rmse:84.6146
#
# fold n°2
# [0]	train-rmse:90.1561	valid_data-rmse:83.4719
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:65.7487	valid_data-rmse:71.0755
# [200]	train-rmse:48.8469	valid_data-rmse:68.7066
# [300]	train-rmse:37.0353	valid_data-rmse:71.3894
# Stopping. Best iteration:
# [177]	train-rmse:52.3048	valid_data-rmse:68.245
#
# fold n°3
# [0]	train-rmse:81.3505	valid_data-rmse:113.832
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:59.6703	valid_data-rmse:95.5133
# [200]	train-rmse:45.2185	valid_data-rmse:84.7287
# [300]	train-rmse:35.5266	valid_data-rmse:79.2213
# [400]	train-rmse:28.4381	valid_data-rmse:75.3814
# [500]	train-rmse:23.484	valid_data-rmse:73.1881
# [600]	train-rmse:19.6955	valid_data-rmse:71.2628
# [700]	train-rmse:16.8837	valid_data-rmse:70.0799
# [800]	train-rmse:14.7645	valid_data-rmse:69.1442
# [900]	train-rmse:13.1679	valid_data-rmse:68.3353
# [1000]	train-rmse:11.969	valid_data-rmse:67.5516
# [1100]	train-rmse:11.0124	valid_data-rmse:67.1231
# [1200]	train-rmse:10.2855	valid_data-rmse:66.7425
# [1300]	train-rmse:9.7164	valid_data-rmse:66.4211
# [1400]	train-rmse:9.27895	valid_data-rmse:66.0787
# [1500]	train-rmse:8.91922	valid_data-rmse:65.7417
# [1600]	train-rmse:8.64634	valid_data-rmse:65.49
# [1700]	train-rmse:8.40638	valid_data-rmse:65.2285
# [1800]	train-rmse:8.20743	valid_data-rmse:65.0712
# [1900]	train-rmse:8.04619	valid_data-rmse:64.9555
# [2000]	train-rmse:7.91168	valid_data-rmse:64.8985
# [2100]	train-rmse:7.76975	valid_data-rmse:64.8423
# [2200]	train-rmse:7.64409	valid_data-rmse:64.7919
# [2300]	train-rmse:7.51647	valid_data-rmse:64.71
# [2400]	train-rmse:7.40134	valid_data-rmse:64.688
# [2500]	train-rmse:7.28592	valid_data-rmse:64.6304
# [2600]	train-rmse:7.17696	valid_data-rmse:64.6135
# [2700]	train-rmse:7.06022	valid_data-rmse:64.5876
# [2800]	train-rmse:6.93982	valid_data-rmse:64.5664
# [2900]	train-rmse:6.83253	valid_data-rmse:64.5745
# [3000]	train-rmse:6.72815	valid_data-rmse:64.5469
# [3100]	train-rmse:6.62312	valid_data-rmse:64.5498
# [3200]	train-rmse:6.51786	valid_data-rmse:64.5438
# [3300]	train-rmse:6.42194	valid_data-rmse:64.5319
# [3400]	train-rmse:6.32706	valid_data-rmse:64.5271
# [3500]	train-rmse:6.21916	valid_data-rmse:64.5243
# [3600]	train-rmse:6.13123	valid_data-rmse:64.5174
# [3700]	train-rmse:6.04719	valid_data-rmse:64.514
# [3800]	train-rmse:5.95636	valid_data-rmse:64.508
# [3900]	train-rmse:5.87576	valid_data-rmse:64.4965
# [4000]	train-rmse:5.78403	valid_data-rmse:64.4947
# [4100]	train-rmse:5.69476	valid_data-rmse:64.4938
# [4200]	train-rmse:5.61858	valid_data-rmse:64.4938
# [4300]	train-rmse:5.53966	valid_data-rmse:64.4883
# [4400]	train-rmse:5.45859	valid_data-rmse:64.4904
# [4500]	train-rmse:5.38771	valid_data-rmse:64.487
# [4600]	train-rmse:5.31186	valid_data-rmse:64.4798
# [4700]	train-rmse:5.2341	valid_data-rmse:64.4774
# [4800]	train-rmse:5.16723	valid_data-rmse:64.4749
# [4900]	train-rmse:5.09343	valid_data-rmse:64.4787
# [5000]	train-rmse:5.0203	valid_data-rmse:64.4782
# Stopping. Best iteration:
# [4812]	train-rmse:5.15887	valid_data-rmse:64.4747
#
# fold n°4
# [0]	train-rmse:95.3224	valid_data-rmse:55.1955
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:69.8371	valid_data-rmse:41.9822
# [200]	train-rmse:52.4901	valid_data-rmse:39.6915
# [300]	train-rmse:40.235	valid_data-rmse:42.5323
# Stopping. Best iteration:
# [191]	train-rmse:53.7133	valid_data-rmse:39.6514
#
# fold n°5
# [0]	train-rmse:91.4057	valid_data-rmse:77.3577
# Multiple eval metrics have been passed: 'valid_data-rmse' will be used for early stopping.
#
# Will train until valid_data-rmse hasn't improved in 200 rounds.
# [100]	train-rmse:67.8181	valid_data-rmse:59.9982
# [200]	train-rmse:51.4679	valid_data-rmse:50.1162
# [300]	train-rmse:40.1661	valid_data-rmse:44.3372
# [400]	train-rmse:31.8628	valid_data-rmse:41.5114
# [500]	train-rmse:25.5947	valid_data-rmse:39.5743
# [600]	train-rmse:20.9143	valid_data-rmse:38.5265
# [700]	train-rmse:17.488	valid_data-rmse:37.8539
# [800]	train-rmse:15.0273	valid_data-rmse:37.4499
# [900]	train-rmse:13.257	valid_data-rmse:37.1653
# [1000]	train-rmse:11.905	valid_data-rmse:36.9566
# [1100]	train-rmse:10.8958	valid_data-rmse:36.7923
# [1200]	train-rmse:10.1373	valid_data-rmse:36.6228
# [1300]	train-rmse:9.61664	valid_data-rmse:36.5682
# [1400]	train-rmse:9.22446	valid_data-rmse:36.4998
# [1500]	train-rmse:8.91514	valid_data-rmse:36.4544
# [1600]	train-rmse:8.67508	valid_data-rmse:36.4054
# [1700]	train-rmse:8.47901	valid_data-rmse:36.3704
# [1800]	train-rmse:8.31438	valid_data-rmse:36.3454
# [1900]	train-rmse:8.16421	valid_data-rmse:36.3135
# [2000]	train-rmse:8.02722	valid_data-rmse:36.2691
# [2100]	train-rmse:7.90271	valid_data-rmse:36.2453
# [2200]	train-rmse:7.77264	valid_data-rmse:36.2138
# [2300]	train-rmse:7.65915	valid_data-rmse:36.1984
# [2400]	train-rmse:7.53601	valid_data-rmse:36.1794
# [2500]	train-rmse:7.43061	valid_data-rmse:36.1639
# [2600]	train-rmse:7.31341	valid_data-rmse:36.1424
# [2700]	train-rmse:7.2091	valid_data-rmse:36.1355
# [2800]	train-rmse:7.09827	valid_data-rmse:36.1215
# [2900]	train-rmse:6.99392	valid_data-rmse:36.1097
# [3000]	train-rmse:6.89774	valid_data-rmse:36.106
# [3100]	train-rmse:6.79428	valid_data-rmse:36.0979
# [3200]	train-rmse:6.68734	valid_data-rmse:36.0948
# [3300]	train-rmse:6.58962	valid_data-rmse:36.0872
# [3400]	train-rmse:6.48205	valid_data-rmse:36.0877
# [3500]	train-rmse:6.38238	valid_data-rmse:36.0846
# [3600]	train-rmse:6.28546	valid_data-rmse:36.08
# [3700]	train-rmse:6.19412	valid_data-rmse:36.0775
# [3800]	train-rmse:6.10594	valid_data-rmse:36.0778
# [3900]	train-rmse:6.01951	valid_data-rmse:36.0752
# [4000]	train-rmse:5.92882	valid_data-rmse:36.0726
# [4100]	train-rmse:5.8407	valid_data-rmse:36.0705
# [4200]	train-rmse:5.76191	valid_data-rmse:36.0695
# [4300]	train-rmse:5.67548	valid_data-rmse:36.07
# [4400]	train-rmse:5.59773	valid_data-rmse:36.07
# Stopping. Best iteration:
# [4216]	train-rmse:5.74968	valid_data-rmse:36.0682
#
# CV score: 3769.45557115
# 12.289471273867893
# cv smape: 1.3855264363066053
# ------------------------------------------------------------------------------------------------------------------
# validation: 21499.620053510196
# 12.386701136245183
# 1.380664943187741
# ------------------------------------------------------------------------------------------------------------------
